# %%
import xml.etree.ElementTree as ET
import pandas as pd
import codecs
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

def parse_execution_plan(xml_file):
    try:
        # Read the file in binary mode first
        with open(xml_file, 'rb') as f:
            content = f.read()
            
        # Try to decode with UTF-16 without BOM
        try:
            xml_content = content.decode('utf-16-le')
            print("Successfully read file with UTF-16-LE encoding")
        except UnicodeDecodeError:
            try:
                xml_content = content.decode('utf-16-be')
                print("Successfully read file with UTF-16-BE encoding")
            except UnicodeDecodeError:
                # Fallback to UTF-8
                xml_content = content.decode('utf-8')
                print("Successfully read file with UTF-8 encoding")
        
        # Parse the XML content
        root = ET.fromstring(xml_content)
        
        # Define the namespace
        ns = {'sp': 'http://schemas.microsoft.com/sqlserver/2004/07/showplan'}
        
        statements = []
        # Initialize lists to store statistics
        stats = []
        
        # First, collect all statements
        for stmt in root.findall('.//sp:StmtSimple', ns):
            stmt_id = stmt.get('StatementId', 'N/A')
            statement = {
                'StatementId': stmt_id,
                'StatementType': stmt.get('StatementType', 'N/A'),
                'StatementText': stmt.get('StatementText', 'N/A')
            }
            statements.append(statement)

            for rel_op in stmt.findall('.//sp:RelOp', ns):
                try:
                    # parent_stmt = rel_op.find('ancestor::QueryPlan::sp:StmtSimple', ns)
                    # stmt_id = parent_stmt.get('StatementId') if parent_stmt is not None else '0'

                    # Extract basic statistics
                    step = {
                        'NodeId': rel_op.get('NodeId', 'N/A'),
                        'StatementId': stmt_id,
                        'PhysicalOp': rel_op.get('PhysicalOp', 'N/A'),
                        'LogicalOp': rel_op.get('LogicalOp', 'N/A'),
                        'EstimateRows': rel_op.get('EstimateRows', 'N/A'),
                        'EstimateCPU': rel_op.get('EstimateCPU', 'N/A'),
                        'EstimateIO': rel_op.get('EstimateIO', 'N/A'),
                        'AvgRowSize': rel_op.get('AvgRowSize', 'N/A'),
                        'Parallel': rel_op.get('Parallel', 'N/A'),
                        'EstimatedTotalSubtreeCost': rel_op.get('EstimatedTotalSubtreeCost', 'N/A')
                    }

                    # Add to stats list
                    stats.append(step)
                except Exception as e:
                    print(f"Warning: Error processing RelOp element: {str(e)}")
                    continue
        
        if not stats:
            raise ValueError("No execution plan statistics found in the XML file")
        
        # Convert to DataFrame
        df = pd.DataFrame(stats)
        
        print(statements)
        print(df.head())
        # Calculate percentages
        try:
            total_cost = float(df['EstimatedTotalSubtreeCost'].iloc[0])
            df['CostPercentage'] = (df['EstimatedTotalSubtreeCost'].astype(float) / total_cost * 100).round(2)
        except (ValueError, TypeError) as e:
            print(f"Warning: Could not calculate cost percentages: {str(e)}")
            df['CostPercentage'] = 0
        
        # Format the output
        df = df[['NodeId', 'PhysicalOp', 'LogicalOp', 'EstimateRows', 'EstimateCPU', 
                 'EstimateIO', 'AvgRowSize', 'Parallel', 'CostPercentage']]
        
        # Rename columns for better readability
        df.columns = ['Node ID', 'Physical Operation', 'Logical Operation', 'Estimated Rows',
                     'CPU Cost', 'IO Cost', 'Avg Row Size', 'Parallel', 'Cost %']
        
        return df
    
    except Exception as e:
        print(f"Error parsing execution plan: {str(e)}")
        raise

# Parse the execution plan
try:
    df = parse_execution_plan('env/sqlexecplanxml.txt')
    
    # Display the full table
    # display(HTML("<h2>SQL Execution Plan Statistics</h2>"))
    # display(df)
    
    # # Create visualizations
    # plt.figure(figsize=(15, 10))
    
    # # Plot 1: Cost Distribution
    # plt.subplot(2, 2, 1)
    # sns.barplot(data=df.nlargest(10, 'Cost %'), x='Cost %', y='Physical Operation')
    # plt.title('Top 10 Most Expensive Operations')
    # plt.xlabel('Cost Percentage')
    
    # # Plot 2: CPU vs IO Cost
    # plt.subplot(2, 2, 2)
    # plt.scatter(df['CPU Cost'].astype(float), df['IO Cost'].astype(float))
    # plt.title('CPU vs IO Cost Distribution')
    # plt.xlabel('CPU Cost')
    # plt.ylabel('IO Cost')
    
    # # Plot 3: Parallel vs Non-Parallel Operations
    # plt.subplot(2, 2, 3)
    # parallel_counts = df['Parallel'].value_counts()
    # plt.pie(parallel_counts, labels=parallel_counts.index, autopct='%1.1f%%')
    # plt.title('Parallel vs Non-Parallel Operations')
    
    # # Plot 4: Estimated Rows Distribution
    # plt.subplot(2, 2, 4)
    # sns.histplot(data=df, x='Estimated Rows', bins=20)
    # plt.title('Distribution of Estimated Rows')
    # plt.xscale('log')
    
    # plt.tight_layout()
    # plt.show()
    
    # Print summary statistics
    print("\nSummary Statistics:")
    print(f"Total number of execution steps: {len(df)}")
    print(f"Most expensive operation: {df.loc[df['Cost %'].idxmax(), 'Physical Operation']} ({df['Cost %'].max():.2f}%)")
    
except Exception as e:
    print(f"Error: {str(e)}")
    print("Please check if the file exists and is a valid SQL Server execution plan XML file.")
# Out:
# Successfully read file with UTF-8 encoding
# [{'StatementId': '1', 'StatementType': 'BEGIN TRANSACTION', 'StatementText': 'BEGIN TRAN\r\n\r\n'}, {'StatementId': '2', 'StatementType': 'ASSIGN', 'StatementText': 'DECLARE \r\n @ClientId INT = NULL, \r\n @DateOfService DATETIME = NULL,\r\n @CreateCaseRateServiceAfterAllServicesCompleted CHAR(1) = NULL\r\n\r\n--SELECT @@SPID\r\n\r\n--exec ssp_GetCaseRateSetupServices_AT\r\n\r\n'}, {'StatementId': '3', 'StatementType': 'SELECT', 'StatementText': "SELECT crs.CaseRateId,\r\n    crs.CaseRateSetupId,\r\n    s.ClientId,\r\n    s.ServiceId,\r\n    s.DateOfService,\r\n    peri.[Code] as PeriodCode,\r\n    case when peri.[Code] = 'Encounter' then psid.PrimaryServiceId else null end as PrimaryServiceId,\r\n    s.Status as ComponentServiceStatus,\r\n    crspc.WriteOffServices,\r\n    crs.AdjustmentCode,\r\n    cr.CreateCaseRateServiceAfterAllServicesCompleted,\r\n    cr.IncludeDiagnosisFromComponentService,\r\n    cr.IncludeDiagnosisFromComponentServiceType,\r\n    CASE WHEN peri.[Code] IN ('Day', 'Week', 'Month', 'Year') THEN periods.PeriodDate \r\n      when peri.[Code] = 'Encounter' then pserv.DateOfService\r\n   else s.DateOfService \r\n    END AS PeriodDate\r\n    FROM dbo.CaseRateSetup crs\r\n   JOIN dbo.CaseRates cr on cr.CaseRateId = crs.CaseRateId\r\n    and isnull(cr.RecordDeleted,'N') <> 'Y' and cr.Active ='Y'\r\n    and (@CreateCaseRateServiceAfterAllServicesCompleted IS NULL OR @CreateCaseRateServiceAfterAllServicesCompleted = cr.CreateCaseRateServiceAfterAllServicesCompleted)\r\n   JOIN dbo.GlobalCodes peri on peri.GlobalCodeId = cr.CasePeriod\r\n    and isnull(peri.RecordDeleted,'N') <> 'Y'\r\n   LEFT JOIN dbo.GlobalCodes dow on dow.GlobalCodeId = cr.CaseRateDay\r\n    and isnull(dow.RecordDeleted,'N') <> 'Y'\r\n   OUTER APPLY (Select case dow.Code when 'Monday' then 2 \r\n             when 'Tuesday' then 3\r\n             when 'Wednesday' then 4\r\n             when 'Thursday' then 5\r\n             when 'Friday' then 6\r\n             when 'Saturday' then 7\r\n             when 'Sunday' then 1 \r\n             end as DayOfWeek\r\n             ) DowEnum\r\n   OUTER APPLY ( Select top (1) -- top 1 is for week - since the period date might be last week we have to consider both this week and last week.\r\n           -- mostly because DatePart(week) is from Sunday to Saturday, but our windows cross that line.\r\n       d.Date as PeriodStart\r\n       ,CASE WHEN peri.[Code] = 'Day' THEN d.Date\r\n            WHEN peri.[Code] = 'Week' THEN DATEADD(DAY, 6, d.Date)\r\n            WHEN peri.[Code] = 'Month' THEN DATEADD(DAY, 30, d.Date)\r\n            WHEN peri.[Code] = 'Year' THEN DATEADD(YEAR, 1, d.Date)\r\n        END AS PeriodEnd\r\n       from dbo.Dates d\r\n       where \r\n       @DateOfService IS NOT NULL AND DATEPART(year,@DateOfService) = d.[Year]\r\n       and \r\n       (     (peri.[Code] = 'Day' and d.[Date] = CAST(@DateOfService as date))\r\n         or (peri.[Code] = 'Week' and  d.WeekNumberOfYear in (DATEPART(week,@DateOfService),DATEPART(week,@DateOfService)-1) and d.[Date] <= @DateOfService and d.DayNumberOfWeek = isnull(dowenum.DayOfWeek,1))\r\n         or (peri.[Code] = 'Month' and DATEPART(MONTH,@DateOfService) = d.[Month] and d.DayNumberOfMonth = 1)\r\n         or (peri.[Code] = 'Year' and d.DayNumberOfYear = 1)\r\n         )\r\n       order by d.date desc  \r\n   ) DateOfServicePeriod\r\n   LEFT JOIN dbo.CaseRateSetupProcedureCodes crspc on crspc.CaseRateSetupId = crs.CaseRateSetupId\r\n    and isnull(crspc.RecordDeleted,'N') <> 'Y'\r\n   LEFT JOIN dbo.CaseRateSetupPrograms crsp on crsp.CaseRateSetupId = crs.CaseRateSetupId\r\n    and isnull(crsp.RecordDeleted,'N') <> 'Y'\r\n   LEFT JOIN dbo.CaseRateSetupLocations crsl on crsl.CaseRateSetupId = crs.CaseRateSetupId\r\n    and isnull(crsl.RecordDeleted,'N') <> 'Y'\r\n   LEFT JOIN dbo.CaseRateSetupModeOfDeliveries crsmod on crsmod.CaseRateSetupId = crs.CaseRateSetupId\r\n    and isnull(crsmod.RecordDeleted,'N') <> 'Y'\r\n            LEFT JOIN dbo.CaseRateSetup ...
#   NodeId StatementId      PhysicalOp            LogicalOp EstimateRows  \
# 0      0           3  Compute Scalar       Compute Scalar    175596000
# 1      1           3     Parallelism       Gather Streams    175596000
# 2      2           3    Nested Loops      Left Outer Join    175596000
# 3      4           3            Sort                 Sort    175596000
# 4      5           3     Parallelism  Repartition Streams    175596000
#
#   EstimateCPU EstimateIO AvgRowSize Parallel EstimatedTotalSubtreeCost
# 0     17.5596          0         68    false                   40269.9
# 1     1291.32          0         85     true                   40252.4
# 2     366.996          0         85     true                     38961
# 3     4131.48    13182.9         81     true                   21002.6
# 4     1582.96          0         81     true                   3688.21
#
# Summary Statistics:
# Total number of execution steps: 156
# Most expensive operation: Compute Scalar (100.00%)
